# %%
import os
import sys
sys.path.append("../scripts")
from angle_calculation import process_all_shells

# === Config ===
COORD_FOLDER = "shells_coordinate_log"
FIELD_FOLDER = "fits_shell_fields"
OUTPUT_FOLDER = "fits_shell_angles_jax_log"

# === Run ===
print("🚀 Starting polarization angle computation (JAX)...")
process_all_shells(COORD_FOLDER, FIELD_FOLDER, OUTPUT_FOLDER)
print("✅ Done.")
# Out:
# 🚀 Starting polarization angle computation (JAX)...
# ✅ Saved: fits_shell_angles_jax_log/angles_0000.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0001.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0002.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0003.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0004.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0005.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0006.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0007.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0008.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0009.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0010.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0011.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0012.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0013.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0014.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0015.fits
# ✅ Saved: fits_shell_angles_jax_log/angles_0016.fits
# ...
