# %%
import os
import sys
sys.path.append("../scripts")
from integrate_GMF_QU_shells_jax import (
    sum_QU_over_shells_jax,
    save_QU_to_fits,
    plot_QU_maps,
)

# === Configuration ===
INPUT_FOLDER = "fits_shell_angles_jax_log"
OUTPUT_FITS = "QU_integrated_over_shells_log.fits"
OUTPUT_PREFIX = "no_dust"
NSIDE = 256

# === Run integration ===
print("🚀 Integrating Q and U over GMF shells...")
Q_map, U_map = sum_QU_over_shells_jax(INPUT_FOLDER)
save_QU_to_fits(Q_map, U_map, OUTPUT_FITS, nside=NSIDE)
plot_QU_maps(Q_map, U_map, output_prefix=OUTPUT_PREFIX)
# Out:
# 🚀 Integrating Q and U over GMF shells...
# ✅ Saved Q and U integrated maps to UF23_QU_integrated_over_shells_log.fits
# ✅ Step 3 complete.
